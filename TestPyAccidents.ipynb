# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("data/accidents.csv")

df = df[["AvyYear","Killed"]]
#df.query('State == "UT" and \'TravelMode\=="Ski"')
#df.query(' PrimaryActivity == "Inbounds Rider"').count()#TravelMode == "Ski" and PrimaryActivity == "Inbounds Rider"').count()
df = df.groupby(["Killed","AvyYear"]).count().reset_index()
df
# Out:
#      Killed  AvyYear
# 0         1     1952
# 1         1     1953
# 2         1     1954
# 3         1     1955
# 4         1     1956
# ..      ...      ...
# 154       5     2013
# 155       6     1999
# 156       6     2014
# 157       7     1962
# 158      11     1981
#
# [159 rows x 2 columns]

# %%
test = pd.read_csv("data/accidents.csv")

test = test[["AvyYear","Killed"]]
result = test.groupby("AvyYear").count().reset_index()

result = result.query('AvyYear > 2000')
result
# Out:
#     AvyYear  Killed
# 50     2001      27
# 51     2002      26
# 52     2003      28
# 53     2004      19
# 54     2005      24
# 55     2006      22
# 56     2007      19
# 57     2008      28
# 58     2009      24
# 59     2010      32
# 60     2011      22
# 61     2012      27
# 62     2013      19
# 63     2014      28
# 64     2015      10
# 65     2016      29
# 66     2017      12
# 67     2018      21
# 68     2019      23
# 69     2020      19
# 70     2021      29
# 71     2022      14

# %%
# Out:
# Empty DataFrame
# Columns: []
# ...
